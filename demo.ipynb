# %%
from kowalskyyy import *
from sklearn.metrics import mean_absolute_error, mean_squared_error
from sklearn.preprocessing import StandardScaler
import matplotlib.pyplot as plt
import pandas as pd

from sklearn.model_selection import train_test_split

# %%
def Metrics(pred, true, model):
    print('Metrics Result of {}'.format(model))
    print('Mean Square Error, {}'.format(mean_squared_error(true, pred)))
    print('Mean Absolute Error, {}'.format(mean_absolute_error(true, pred)))

# %% [markdown]
# # Linear Regression

# %%
data = pd.read_csv('data/salary_data.csv')

X = data.iloc[:, :-1].values
y = data.iloc[:, -1].values

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

lr = LinearRegression()
lr.fit(X_train, y_train)
pred = lr.predict(X_test)

# %%
Metrics(pred, y_test, 'Linear Regression')
# Out:
# Metrics Result of Linear Regression
# Mean Square Error, 15873447.390615383
# Mean Absolute Error, 3151.4969921039615

# %%
plt.figure(figsize=(8, 6))

plt.plot(y_test, 'r-', label='Ground Truth')
plt.plot(pred, 'b-', label='Prediction')
plt.legend()
plt.show()

# %% [markdown]
# ## PCA

# %%
data = pd.read_csv('data/diabetes.csv')
data.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %%
X = data.iloc[:, :-1].values
y = data.iloc[:, -1].values

# %%
pca = PCA(n_components=2)
scale = StandardScaler()
X_scale = scale.fit_transform(X)
pca.fit(X_scale)
X_transform_scratch = pca.transform(X_scale)

# %%
plt.figure(figsize=(6, 6))
plt.scatter(X_transform_scratch[:,0], X_transform_scratch[:, 1], c ='red')
plt.plot()
# Out:
# []

# %%
from sklearn.decomposition import PCA

pca = PCA(n_components=2)
scale = StandardScaler()
X_scale = scale.fit_transform(X)
pca.fit(X_scale)
X_transform = pca.transform(X_scale)
plt.figure(figsize=(6, 6))
plt.scatter(X_transform[:,0], X_transform[:, 1])
plt.plot()
# Out:
# []

# %%
plt.figure(figsize=(8, 8))
plt.scatter(X_transform[:, 0], X_transform[:, 1], c='g', marker='^')
plt.scatter(X_transform_scratch[:, 0], X_transform_scratch[:, 1], c='r', marker='o')

plt.show()

# %%
plt.figure(figsize=(8, 8))
plt.scatter(X_transform[:, 0], X_transform[:, 1], c='g', marker='^')
plt.scatter(X_transform_scratch[:, 0], -X_transform_scratch[:, 1], c='r', marker='o')

plt.show()

# %% [markdown]
# ## KNN Regression

# %%
data = pd.read_csv('data/salary_data.csv')
X = data.iloc[:, :-1].values
y = data.iloc[:, -1].values

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

# %%
knn_regressor = KNeighborsRegression(n_neighbors=4, p=2)
knn_regressor.fit(X_train, y_train)
knn_predict = knn_regressor.predict(X_test)

Metrics(knn_predict, y_test, 'KNN Regression')
# Out:
# Metrics Result of KNN Regression
# Mean Square Error, 49165321.614583336
# Mean Absolute Error, 6043.291666666667

# %%
plt.figure(figsize=(8, 6))

plt.plot(y_test, 'r-', label='Ground Truth')
plt.plot(knn_predict, 'b-', label='Prediction')
plt.legend()
plt.show()
